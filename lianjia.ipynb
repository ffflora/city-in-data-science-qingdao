# %%
# 安居客
import requests
from bs4 import BeautifulSoup
import pandas as pd

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:67.0) Gecko/20100101 Firefox/67.0'}
result = pd.DataFrame(columns=['name', 'price','unit_price',
                               'room_type', 'area','floor',
                               'year', 'broker','address', 'tag'])
for i in range(1,50):
    print('Page',i)
    link = 'https://qd.anjuke.com/sale/p' + str(i)
    r =requests.get(link,headers = headers)
    soup=BeautifulSoup(r.text,'lxml')
    house_list = soup.find_all('li',class_='list-item')
    for house in house_list:
        name = house.find('div', class_='house-title').a.text.strip()
        price = house.find('span',class_='price-det').text.strip()
        unit_price = house.find('span',class_= 'unit-price').text.strip()
        room_type = house.find('div',class_='details-item').span.text
        area = house.find('div',class_='details-item').contents[3].text
        floor = house.find('div',class_='details-item').contents[5].text
        year = house.find('div',class_='details-item').contents[7].text
        broker = house.find('span',class_='broker-name broker-text').text
        address = house.find('span',class_='comm-address').text
        tags_list = house.find_all('div',class_='tags-bottom')
        tag = ','.join([i.text for i in tags_list])
 
        new_li=[name,price,unit_price,room_type, area,
                                floor,year,broker,address, tag]
        new_li = pd.DataFrame(new_li)
        #result.append(new_li)
        #print(new_li)
        """with open('save-files/anjuke.csv','a+')as f:
            f.write(new_li)
        """
        with open('save-files/anjuke50.csv','a',encoding="utf-8")as f:
            new_li.to_csv(f,header=False)
        #print(result)
    time.sleep(5)

# %%
# lianjia
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

sleep_time = random.randint(0,2)+random.random()

     
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'}

#result = pd.DataFrame(columns=['name', 'price','unit_price',
 #                              'house_info', 'follow','floor_pos','tag'])
for i in range(81,101):
    print('Page',i)
    result = pd.DataFrame()
    link = 'https://qd.lianjia.com/ershoufang/pg' + str(i)
    r =requests.get(link,headers = headers)
    soup=BeautifulSoup(r.text,'lxml')
    house_list = soup.find_all('li',class_='clear LOGCLICKDATA')
    for house in house_list:
        name = house.find('div', class_='title').a.text.strip()
        price = house.find('div',class_='totalPrice').span.text
        unit_price = house.find('div',class_= 'unitPrice').span.text.strip()
        house_info = house.find('div',class_='address').text
        floor_pos = house.find('div',class_='positionInfo').text
        #room_type = house.find('div',class_='details-item').span.text
        #area = house.find('div',class_='details-item').contents[3].text
        follow = house.find('div',class_='followInfo').text
        tags_list = house.find_all('div',class_='tag')
        tag = ','.join([i.text.strip('') for i in tags_list])
 
        testlist = [name,price,unit_price,house_info,follow,
                   floor_pos,tag]
        newlist = pd.DataFrame(testlist).T
       # print(name,'\n',price,'\n',unit_price,'\n',house_info,
        #      '\n',follow,'\n', floor_pos,tag,'\n\n')
        result = result.append(newlist)
        time.sleep(0.5)
    with open('save-files/lianjia100.csv','a',encoding="utf-8")as f:
        result.to_csv(f,header=False)
    time.sleep(sleep_time)
      #  print(new_li)
# Out:
# Page 81
# Page 82
# Page 83
# Page 84
# Page 85
# Page 86
# Page 87
# Page 88
# Page 89
# Page 90
# Page 91
# Page 92
# Page 93
# Page 94
# Page 95
# Page 96
# Page 97
# Page 98
# Page 99
# Page 100

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 0
# Data columns (total 7 columns):
# 0    30 non-null object
# 1    30 non-null object
# 2    30 non-null object
# 3    30 non-null object
# 4    30 non-null object
# 5    30 non-null object
# 6    30 non-null object
# dtypes: object(7)
# memory usage: 1.9+ KB

# %%
test22 = pd.read_csv('save-files/lianjia100.csv')
test22
# Out:
#       0           精装套一，干湿分离，12年新小区，位置好     92  单价12264元/平米  \
# 0     0               经典套二  南北通透格局 采光好  127.0  单价14672元/平米
# 1     0           怡和嘉园北区 精装修  交通便利 新小区  130.0  单价15145元/平米
# 2     0        万达广场  经典正规套二   楼层好 随时看房  190.0  单价22801元/平米
# 3     0         怡和嘉园，70年产权  南北卧，西厅，采光好  130.0  单价14445元/平米
# 4     0        15年小区 明厨 明卫户型 生活方便 交通便利  130.0  单价15336元/平米
# 5     0  磊鑫伊顿阳光套二户型 86.34平130万可塑性强 视野棒  128.0  单价14826元/平米
# 6     0               卓越蔚蓝群岛 2室2厅 120万  120.0  单价12893元/平米
# 7     0          全明户型，格局好 套二户型，客厅厨房带阳台  100.0  单价13560元/平米
# 8     0      山水名园三期 多层三居室 楼层合适 户型方正带车位  550.0  单价43094元/平米
# 9     0                  观澜国际 2室2厅 92万   92.0  单价11795元/平米
# 10    0               星河城三期20万装修套三，总价低  128.0  单价14291元/平米
# 11    0          天一畔城 美林居 好楼层视野开阔 交通便利  129.0  单价11584元/平米
# 12    0     千禧银杏苑 精装套二 南北通透 全明户型 14年建成  140.0  单价15772元/平米
# 13    0          精装修 南北通透大两居  看好即可拎包入住  188.0  单价20610元/平米
# 14    0       保利海上罗兰 精装套二 海景房 拎包入住 不靠路  143.0  单价16102元/平米
# ...

# %%
# lianjia
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

sleep_time = random.randint(0,2)+random.random()

     
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:67.0) Gecko/20100101 Firefox/67.0'}

#result = pd.DataFrame(columns=['name', 'price','unit_price',
 #                              'house_info', 'follow','floor_pos','tag'])
for i in range(1,101):
    print('Page',i)
    result = pd.DataFrame()
    link = 'https://qd.lianjia.com/chengjiao/' + str(i)
    r =requests.get(link,headers = headers)
    soup=BeautifulSoup(r.text,'lxml')
    house_list = soup.find('ul',class_='listContent').contents
    for house in house_list:
        try:
            name = house.find('div', class_='title').text.strip()
            date = house.find('div',class_='dealDate').text
            price = house.find('div',class_='totalPrice').span.text
            unit_price = house.find('div',class_= 'unitPrice').span.text.strip()
            house_info = house.find('div',class_='houseInfo').text
            floor_pos = house.find('div',class_='positionInfo').text
            deal_info = house.find('span',class_='dealHouseTxt').text
            deal_cycle = house.find('span',class_='dealCycleTxt').text
            agent = house.find('div',class_='agentInfoList').a.text
            testlist = [name,date,price,unit_price,house_info,floor_pos,deal_info,deal_cycle,agent]
            newlist = pd.DataFrame(testlist).T
            result = result.append(newlist)
            time.sleep(0.5)
            with open('data/lianjiaDeal.csv','a',encoding="utf-8")as f:
                result.to_csv(f,header=False)
    
            #print(name,'\n',date,'\n',price,'\n',unit_price,'\n',house_info,
             #     '\n',deal_info,'\n', floor_pos,'\n',deal_cycle,'\n\n',agent,'\n')
        except AttributeError:
            pass
        time.sleep(sleep_time)

    """ 
        testlist = [name,price,unit_price,house_info,follow,
                   floor_pos,tag]
        newlist = pd.DataFrame(testlist).T
        result = result.append(newlist)
        time.sleep(0.5)
    with open('save-files/lianjia100.csv','a',encoding="utf-8")as f:
        result.to_csv(f,header=False)
    time.sleep(sleep_time)
      
      """
# Out:
# Page 1
# Page 2
# Page 3
# Page 4
# Page 5
# Page 6
# Page 7
# Page 8
# Page 9
# Page 10
# Page 11
# Page 12
# Page 13
# Page 14
# Page 15
# Page 16
# Page 17
# Page 18
# Page 19
# Page 20
# Page 21
# Page 22
# Page 23
# Page 24
# Page 25
# Page 26
# Page 27
# Page 28
# Page 29
# Page 30
# Page 31
# Page 32
# Page 33
# Page 34
# Page 35
# Page 36
# Page 37
# Page 38
# Page 39
# Page 40
# Page 41
# Page 42
# Page 43
# Page 44
# Page 45
# Page 46
# Page 47
# Page 48
# Page 49
# Page 50
# Page 51
# Page 52
# Page 53
# Page 54
# Page 55
# Page 56
# Page 57
# Page 58
# Page 59
# Page 60
# Page 61
# Page 62
# Page 63
# Page 64
# Page 65
# Page 66
# Page 67
# Page 68
# Page 69
# Page 70
# Page 71
# Page 72
# Page 73
# Page 74
# Page 75
# Page 76
# Page 77
# Page 78
# Page 79
# Page 80
# Page 81
# Page 82
# Page 83
# Page 84
# Page 85
# Page 86
# Page 87
# Page 88
# Page 89
# Page 90
# Page 91
# Page 92
# Page 93
# Page 94
# Page 95
# Page 96
# Page 97
# Page 98
# Page 99
# Page 100
